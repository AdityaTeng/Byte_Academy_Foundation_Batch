# %%
import json
import requests
import datetime

location = 'Bangalore'
country = 'IN'

def WeatherTime(dt):
	dtItem=datetime.datetime.fromtimestamp(dt).strftime('%Y-%m-%d %H:%M:%S')
	dtList=dtItem.split(' ')
	return dtList

url='http://api.openweathermap.org/data/2.5/forecast?q='+location+','+country+'&units=imperial&APPID=1960401d79b51d8c3be286b9463a081b'
source=requests.get(url)
weather=json.loads(source.text)
weatherList=[]
weather['list']
# for weatherItem in weather['list']:
#     weatherList.append([WeatherTime(weatherItem['dt'])[0],WeatherTime(weatherItem['dt'])[1],location,country,weatherItem['main']['temp'],weatherItem['main']['temp_min'],weatherItem['main']['temp_max'],weatherItem['wind']['speed'],weatherItem['clouds']['all'],weatherItem['main']['humidity']])
#     print(weatherList)
# Out:
# [{'dt': 1569607200,
#   'main': {'temp': 72.45,
#    'temp_min': 72.09,
#    'temp_max': 72.45,
#    'pressure': 1015.29,
#    'sea_level': 1015.29,
#    'grnd_level': 918.22,
#    'humidity': 81,
#    'temp_kf': 0.2},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 6.4, 'deg': 129.949},
#   'rain': {'3h': 0.438},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-27 18:00:00'},
#  {'dt': 1569618000,
#   'main': {'temp': 71.24,
#    'temp_min': 70.97,
#    'temp_max': 71.24,
#    'pressure': 1013.96,
#    'sea_level': 1013.96,
#    'grnd_level': 916.83,
#    'humidity': 81,
#    'temp_kf': 0.15},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 93},
#   'wind': {'speed': 3.74, 'deg': 181.614},
#   'rain': {'3h': 0.625},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-27 21:00:00'},
#  {'dt': 1569628800,
#   'main': {'temp': 69.51,
#    'temp_min': 69.32,
#    'temp_max': 69.51,
#    'pressure': 1014.41,
#    'sea_level': 1014.41,
#    'grnd_level': 917.27,
#    'humidity': 85,
#    'temp_kf': 0.1},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 2.48, 'deg': 182.523},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-28 00:00:00'},
#  {'dt': 1569639600,
#   'main': {'temp': 73.94,
#    'temp_min': 73.85,
#    'temp_max': 73.94,
#    'pressure': 1015.57,
#    'sea_level': 1015.57,
#    'grnd_level': 918.51,
#    'humidity': 76,
#    'temp_kf': 0.05},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 59},
#   'wind': {'speed': 4.88, 'deg': 201.586},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-28 03:00:00'},
#  {'dt': 1569650400,
#   'main': {'temp': 81.08,
#    'temp_min': 81.08,
#    'temp_max': 81.08,
#    'pressure': 1013.4,
#    'sea_level': 1013.4,
#    'grnd_level': 917.08,
#    'humidity': 59,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 71},
#   'wind': {'speed': 6.08, 'deg': 191.595},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-28 06:00:00'},
#  {'dt': 1569661200,
#   'main': {'temp': 83.93,
#    'temp_min': 83.93,
#    'temp_max': 83.93,
#    'pressure': 1009.73,
#    'sea_level': 1009.73,
#    'grnd_level': 913.97,
#    'humidity': 52,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.64, 'deg': 203.67},
#   'rain': {'3h': 0.188},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-28 09:00:00'},
#  {'dt': 1569672000,
#   'main': {'temp': 79.54,
#    'temp_min': 79.54,
#    'temp_max': 79.54,
#    'pressure': 1010.11,
#    'sea_level': 1010.11,
#    'grnd_level': 914.39,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 5.37, 'deg': 162.878},
#   'rain': {'3h': 1.437},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-28 12:00:00'},
#  {'dt': 1569682800,
#   'main': {'temp': 73.84,
#    'temp_min': 73.84,
#    'temp_max': 73.84,
#    'pressure': 1013.43,
#    'sea_level': 1013.43,
#    'grnd_level': 916.93,
#    'humidity': 74,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 10.63, 'deg': 130.376},
#   'rain': {'3h': 3.875},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-28 15:00:00'},
#  {'dt': 1569693600,
#   'main': {'temp': 71.9,
#    'temp_min': 71.9,
#    'temp_max': 71.9,
#    'pressure': 1014.33,
#    'sea_level': 1014.33,
#    'grnd_level': 917.27,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 5.64, 'deg': 150.689},
#   'rain': {'3h': 1},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-28 18:00:00'},
#  {'dt': 1569704400,
#   'main': {'temp': 70.3,
#    'temp_min': 70.3,
#    'temp_max': 70.3,
#    'pressure': 1012.86,
#    'sea_level': 1012.86,
#    'grnd_level': 916.01,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 5.7, 'deg': 138.575},
#   'rain': {'3h': 0.438},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-28 21:00:00'},
#  {'dt': 1569715200,
#   'main': {'temp': 69.12,
#    'temp_min': 69.12,
#    'temp_max': 69.12,
#    'pressure': 1013.25,
#    'sea_level': 1013.25,
#    'grnd_level': 916.1,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 4.99, 'deg': 142.477},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-29 00:00:00'},
#  {'dt': 1569726000,
#   'main': {'temp': 73.31,
#    'temp_min': 73.31,
#    'temp_max': 73.31,
#    'pressure': 1015.29,
#    'sea_level': 1015.29,
#    'grnd_level': 918.48,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.19, 'deg': 161.487},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-29 03:00:00'},
#  {'dt': 1569736800,
#   'main': {'temp': 81.2,
#    'temp_min': 81.2,
#    'temp_max': 81.2,
#    'pressure': 1013.46,
#    'sea_level': 1013.46,
#    'grnd_level': 917.16,
#    'humidity': 54,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.42, 'deg': 142.62},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-29 06:00:00'},
#  {'dt': 1569747600,
#   'main': {'temp': 81.08,
#    'temp_min': 81.08,
#    'temp_max': 81.08,
#    'pressure': 1010.66,
#    'sea_level': 1010.66,
#    'grnd_level': 915.08,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 7.58, 'deg': 153.133},
#   'rain': {'3h': 1.75},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-29 09:00:00'},
#  {'dt': 1569758400,
#   'main': {'temp': 77.49,
#    'temp_min': 77.49,
#    'temp_max': 77.49,
#    'pressure': 1010.79,
#    'sea_level': 1010.79,
#    'grnd_level': 914.99,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 7.54, 'deg': 152.189},
#   'rain': {'3h': 1.25},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-29 12:00:00'},
#  {'dt': 1569769200,
#   'main': {'temp': 73.39,
#    'temp_min': 73.39,
#    'temp_max': 73.39,
#    'pressure': 1013.37,
#    'sea_level': 1013.37,
#    'grnd_level': 917.1,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.58, 'deg': 133.855},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-29 15:00:00'},
#  {'dt': 1569780000,
#   'main': {'temp': 71.3,
#    'temp_min': 71.3,
#    'temp_max': 71.3,
#    'pressure': 1013.89,
#    'sea_level': 1013.89,
#    'grnd_level': 917.16,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.42, 'deg': 110.346},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-29 18:00:00'},
#  {'dt': 1569790800,
#   'main': {'temp': 69.98,
#    'temp_min': 69.98,
#    'temp_max': 69.98,
#    'pressure': 1012.25,
#    'sea_level': 1012.25,
#    'grnd_level': 915.51,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.11, 'deg': 111.432},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-29 21:00:00'},
#  {'dt': 1569801600,
#   'main': {'temp': 68.25,
#    'temp_min': 68.25,
#    'temp_max': 68.25,
#    'pressure': 1012.41,
#    'sea_level': 1012.41,
#    'grnd_level': 915.61,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.64, 'deg': 114.478},
#   'rain': {'3h': 0.188},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-30 00:00:00'},
#  {'dt': 1569812400,
#   'main': {'temp': 73.66,
#    'temp_min': 73.66,
#    'temp_max': 73.66,
#    'pressure': 1014.5,
#    'sea_level': 1014.5,
#    'grnd_level': 917.71,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 8.12, 'deg': 119.156},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-30 03:00:00'},
#  {'dt': 1569823200,
#   'main': {'temp': 80.15,
#    'temp_min': 80.15,
#    'temp_max': 80.15,
#    'pressure': 1013.32,
#    'sea_level': 1013.32,
#    'grnd_level': 917.33,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 10.25, 'deg': 148.512},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-30 06:00:00'},
#  {'dt': 1569834000,
#   'main': {'temp': 81.07,
#    'temp_min': 81.07,
#    'temp_max': 81.07,
#    'pressure': 1009.73,
#    'sea_level': 1009.73,
#    'grnd_level': 914.18,
#    'humidity': 62,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 85},
#   'wind': {'speed': 10.85, 'deg': 133.387},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-30 09:00:00'},
#  {'dt': 1569844800,
#   'main': {'temp': 77.99,
#    'temp_min': 77.99,
#    'temp_max': 77.99,
#    'pressure': 1009.86,
#    'sea_level': 1009.86,
#    'grnd_level': 913.99,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 9.28, 'deg': 146.697},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-09-30 12:00:00'},
#  {'dt': 1569855600,
#   'main': {'temp': 72.98,
#    'temp_min': 72.98,
#    'temp_max': 72.98,
#    'pressure': 1012.85,
#    'sea_level': 1012.85,
#    'grnd_level': 916.39,
#    'humidity': 81,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 9.66, 'deg': 140.719},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-30 15:00:00'},
#  {'dt': 1569866400,
#   'main': {'temp': 71.02,
#    'temp_min': 71.02,
#    'temp_max': 71.02,
#    'pressure': 1013.48,
#    'sea_level': 1013.48,
#    'grnd_level': 916.7,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 9.01, 'deg': 173.69},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-30 18:00:00'},
#  {'dt': 1569877200,
#   'main': {'temp': 69.17,
#    'temp_min': 69.17,
#    'temp_max': 69.17,
#    'pressure': 1012.15,
#    'sea_level': 1012.15,
#    'grnd_level': 915.35,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 7.43, 'deg': 170.629},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-09-30 21:00:00'},
#  {'dt': 1569888000,
#   'main': {'temp': 67.91,
#    'temp_min': 67.91,
#    'temp_max': 67.91,
#    'pressure': 1012.66,
#    'sea_level': 1012.66,
#    'grnd_level': 915.66,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 89},
#   'wind': {'speed': 2.86, 'deg': 201.402},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-01 00:00:00'},
#  {'dt': 1569898800,
#   'main': {'temp': 73.49,
#    'temp_min': 73.49,
#    'temp_max': 73.49,
#    'pressure': 1014.56,
#    'sea_level': 1014.56,
#    'grnd_level': 917.76,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 5.86, 'deg': 225.355},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-01 03:00:00'},
#  {'dt': 1569909600,
#   'main': {'temp': 80.09,
#    'temp_min': 80.09,
#    'temp_max': 80.09,
#    'pressure': 1012.92,
#    'sea_level': 1012.92,
#    'grnd_level': 916.8,
#    'humidity': 62,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 6.51, 'deg': 237.281},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-01 06:00:00'},
#  {'dt': 1569920400,
#   'main': {'temp': 83.8,
#    'temp_min': 83.8,
#    'temp_max': 83.8,
#    'pressure': 1009.35,
#    'sea_level': 1009.35,
#    'grnd_level': 913.74,
#    'humidity': 54,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 13},
#   'wind': {'speed': 7.23, 'deg': 238.851},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-01 09:00:00'},
#  {'dt': 1569931200,
#   'main': {'temp': 79.31,
#    'temp_min': 79.31,
#    'temp_max': 79.31,
#    'pressure': 1009.05,
#    'sea_level': 1009.05,
#    'grnd_level': 913.63,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': {'all': 46},
#   'wind': {'speed': 1.66, 'deg': 200.056},
#   'rain': {'3h': 4.375},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-01 12:00:00'},
#  {'dt': 1569942000,
#   'main': {'temp': 74.75,
#    'temp_min': 74.75,
#    'temp_max': 74.75,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 915.66,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 67},
#   'wind': {'speed': 3.18, 'deg': 130.36},
#   'rain': {'3h': 8.062},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-01 15:00:00'},
#  {'dt': 1569952800,
#   'main': {'temp': 72.77,
#    'temp_min': 72.77,
#    'temp_max': 72.77,
#    'pressure': 1013.05,
#    'sea_level': 1013.05,
#    'grnd_level': 916.47,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 3.83, 'deg': 215.429},
#   'rain': {'3h': 9.813},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-01 18:00:00'},
#  {'dt': 1569963600,
#   'main': {'temp': 70.79,
#    'temp_min': 70.79,
#    'temp_max': 70.79,
#    'pressure': 1012.21,
#    'sea_level': 1012.21,
#    'grnd_level': 915.47,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 53},
#   'wind': {'speed': 4.88, 'deg': 315.892},
#   'rain': {'3h': 3.812},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-01 21:00:00'},
#  {'dt': 1569974400,
#   'main': {'temp': 68.65,
#    'temp_min': 68.65,
#    'temp_max': 68.65,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 916.07,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 4.97, 'deg': 301.057},
#   'rain': {'3h': 3.313},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-02 00:00:00'},
#  {'dt': 1569985200,
#   'main': {'temp': 73.79,
#    'temp_min': 73.79,
#    'temp_max': 73.79,
#    'pressure': 1015.1,
#    'sea_level': 1015.1,
#    'grnd_level': 918.32,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 86},
#   'wind': {'speed': 5.39, 'deg': 281.156},
#   'rain': {'3h': 1.938},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-02 03:00:00'},
#  {'dt': 1569996000,
#   'main': {'temp': 80.45,
#    'temp_min': 80.45,
#    'temp_max': 80.45,
#    'pressure': 1013.16,
#    'sea_level': 1013.16,
#    'grnd_level': 917.06,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 43},
#   'wind': {'speed': 5.59, 'deg': 297.048},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-02 06:00:00'},
#  {'dt': 1570006800,
#   'main': {'temp': 83.21,
#    'temp_min': 83.21,
#    'temp_max': 83.21,
#    'pressure': 1009.52,
#    'sea_level': 1009.52,
#    'grnd_level': 913.89,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 4.92, 'deg': 305.922},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-02 09:00:00'},
#  {'dt': 1570017600,
#   'main': {'temp': 79.63,
#    'temp_min': 79.63,
#    'temp_max': 79.63,
#    'pressure': 1009.56,
#    'sea_level': 1009.56,
#    'grnd_level': 914,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 54},
#   'wind': {'speed': 4.43, 'deg': 345.767},
#   'rain': {'3h': 2.875},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2019-10-02 12:00:00'},
#  {'dt': 1570028400,
#   'main': {'temp': 75.29,
#    'temp_min': 75.29,
#    'temp_max': 75.29,
#    'pressure': 1012.19,
#    'sea_level': 1012.19,
#    'grnd_level': 915.96,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 53},
#   'wind': {'speed': 4.65, 'deg': 18.941},
#   'rain': {'3h': 2.688},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2019-10-02 15:00:00'}]
