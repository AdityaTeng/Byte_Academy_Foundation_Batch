# %% [markdown]
# # Algorithm
#
#     An algorithm is any well-deﬁned computational procedure that takes some value, or set of values, as input and produces some value, or set of values, as output. An algorithm is thus a sequence of computational steps that transform the input into the output.
#
#     We can also view an algorithm as a tool for solving a well-speciﬁed computational problem. The statement of theproblem speciﬁes in general terms the desired input/output relationship. The algorithm describes a speciﬁc computational procedure for achieving that input/output relationship.
#
#     For example, we might need to sort a sequence of numbers into nondecreasing order. This problem arises frequently in practice and provides fertile ground for introducing many standard design techniques and analysis tools.
#
#     Here is how we formally deﬁne the sorting problem:
#
#     Input: A sequence of n numbers - (a1, a2, a3, a4....an)
#
#     Output: A permutation (reordering) -  (a1', a2', a3', a4',....an') of the input sequence such that
#             a1' < a2' < a3' < a4'<.... < an'

# %% [markdown]
# # Bubble Sort

# %%
def bubble_sort(arr):
    # For every element (arranged backwards)
    print(arr)
    for n in range(len(arr)-1, 0, -1):
        for k in range(n):
            print('n-', n, 'position k - ', k, 'value arr[k] ', arr[k], 'position [k+1] ', k+1, 'value: arr[k+1]: ', arr[k+1] )
            # If we come to a point to switch
            if arr[k]>arr[k+1]:
                temp = arr[k]
                print('temp: ', temp, "arr[k]: ", arr[k] )
                arr[k] = arr[k+1]
                print("arr[k]: ", arr[k])
                arr[k+1] = temp
                print("arr[k+1]: ", arr[k+1])
                print(arr,'\n')
    print(arr)

# %%
a = 10
b = 20

temp = 10
a = b
b = temp
print(a, b)
# Out:
# 20 10

# %%
def bubble_sort(arr):
    for n in range(len(arr)-1, 0, -1):          # n 3 to 0 >>> n=3      k=0 >>> k=1 >>> k=2
        for k in range(n):                      # n=2            k=0 >> k=1 
            if arr[k]>arr[k+1]:
                temp = arr[k]
                arr[k] = arr[k+1]
                arr[k+1] = temp
    print(arr)

# %%
l = [4,3,2,1]
bubble_sort(l)
# Out:
# [4, 3, 2, 1]
# n- 3 position k -  0 value arr[k]  4 position [k+1]  1 value: arr[k+1]:  3
# temp:  4 arr[k]:  4
# arr[k]:  3
# arr[k+1]:  4
# [3, 4, 2, 1]
#
# n- 3 position k -  1 value arr[k]  4 position [k+1]  2 value: arr[k+1]:  2
# temp:  4 arr[k]:  4
# arr[k]:  2
# arr[k+1]:  4
# [3, 2, 4, 1]
#
# n- 3 position k -  2 value arr[k]  4 position [k+1]  3 value: arr[k+1]:  1
# temp:  4 arr[k]:  4
# arr[k]:  1
# arr[k+1]:  4
# [3, 2, 1, 4]
#
# n- 2 position k -  0 value arr[k]  3 position [k+1]  1 value: arr[k+1]:  2
# temp:  3 arr[k]:  3
# arr[k]:  2
# arr[k+1]:  3
# [2, 3, 1, 4]
#
# n- 2 position k -  1 value arr[k]  3 position [k+1]  2 value: arr[k+1]:  1
# temp:  3 arr[k]:  3
# arr[k]:  1
# arr[k+1]:  3
# [2, 1, 3, 4]
#
# n- 1 position k -  0 value arr[k]  2 position [k+1]  1 value: arr[k+1]:  1
# temp:  2 arr[k]:  2
# arr[k]:  1
# arr[k+1]:  2
# [1, 2, 3, 4]
#
# [1, 2, 3, 4]

# %%
# https://www.geeksforgeeks.org/bubble-sort/
# http://www.cs.armstrong.edu/liang/animation/web/BubbleSort.html

# %% [markdown]
# # Insertion Sort

# %%
def insertion_sort(arr):
    
    # For every index in array
    for i in range(1, len(arr)):
        
        # Set current values and position
        
        p = i                  # p = position
        cv = arr[p]            # cv = current_value
        print(i, cv, end = '----' )
        
        # Sorted Sublist
        while p>0 and arr[p-1]>cv:
            print(i, cv, '\n')
            arr[p]=arr[p-1]
            p = p-1

        arr[p]=cv
    
    return arr

# %%
arr = [4,3,2,1]
insertion_sort(arr)
# Out:
# 1 3----1 3
#
# 2 2----2 2
#
# 2 2
#
# 3 1----3 1
#
# 3 1
#
# 3 1
# [1, 2, 3, 4]

# %%
'''arr = [4,3,2,1]
i: 1 to 3.
i1:  i =1, p=1 , cv = arr[1] = 3
    w1: arr[p-1]>cv: 4>3:
        arr[1] = arr[0]
        p = p-1         [4,4,2,1]
    arr[0] = 3          [3,4,2,1]
i2: i=2, p=2, cv = 2
    w1: 2>0, arr[1]>cv: 4>2:
        arr[2] = arr[1]
        p = p-1         [3,4,4,1]
    w2: 1>0, arr[0]>cv :3>2:
        arr[1] = arr[0]
        p = p-1         [3,3,4,1]
	arr[0] = 2				[2,3,4,1]
i3: i=3, p=3, cv = 1
	w1: 3>0, arr[2]>cv: 4>1
		arr[3]=arr[2]
		p=p-1 			[2,3,4,4]
	w2: 2>0, arr[1]>cv: 3>1
		arr[2]=arr[1]
		p=p-1			[2,3,3,4]
	w3: 1>0, arr[0]>cv: 2>1
		arr[1]= arr[0]
		p=p-1			[2,2,3,4]
	arr[0]=1			1,2,3,4]


Link: http://cs.armstrong.edu/liang/animation/web/InsertionSort.html
'''
print()

# %%
arr = [1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Merge Sort

# %%
def merge_sort(arr):
    if len(arr)>1:                 # arr = [2,1]
        mid = int(len(arr)/2)      # mid = 1
        lefthalf = arr[:mid]       # lefthalf = [2]
        righthalf = arr[mid:]      # righthalf = [1]

        merge_sort(lefthalf)
        merge_sort(righthalf)

        i=0
        j=0
        k=0
#         print('x', lefthalf, righthalf)
        
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                arr[k]=lefthalf[i]
                i=i+1
            else:
                arr[k]=righthalf[j]
                j=j+1
            k=k+1
#             print('y', lefthalf, righthalf)

        while i < len(lefthalf):
            arr[k]=lefthalf[i]
            i=i+1
            k=k+1
#             print('z', lefthalf, righthalf)

        while j < len(righthalf):
            arr[k]=righthalf[j]
            j=j+1
            k=k+1
#             print('a', lefthalf, righthalf)
        return arr
    
merge_sort([2,1])
# Out:
# [1, 2]

# %%
arr = [4,3,7,2,1]
print(arr[:2])
merge_sort(arr)
arr
# Out:
# [4, 3]
# x [4] [3]
# y [4] [3]
# z [4] [3]
# x [2] [1]
# y [2] [1]
# z [2] [1]
# x [7] [1, 2]
# y [7] [1, 2]
# y [7] [1, 2]
# z [7] [1, 2]
# x [3, 4] [1, 2, 7]
# y [3, 4] [1, 2, 7]
# y [3, 4] [1, 2, 7]
# y [3, 4] [1, 2, 7]
# y [3, 4] [1, 2, 7]
# a [3, 4] [1, 2, 7]
# [1, 2, 3, 4, 7]

# %% [markdown]
# # Sequential Search

# %%
import random
from time import gmtime, strftime, time
# Out:
# [4047,
#  1401,
#  8646,
#  905,
#  6367,
#  5119,
#  6302,
#  2193,
#  7138,
#  4457,
#  2007,
#  9644,
#  7020,
#  3593,
#  1963,
#  2532,
#  2487,
#  8597,
#  1046,
#  9777,
#  9337,
#  1999,
#  2660,
#  4012,
#  5338,
#  6156,
#  98,
#  3098,
#  3705,
#  4189,
#  9204,
#  9424,
#  5464,
#  694,
#  2089,
#  9387,
#  7930,
#  5821,
#  3169,
#  774,
#  2391,
#  8074,
#  4292,
#  8775,
#  2415,
#  6458,
#  8932,
#  3819,
#  8302,
#  4919,
#  6634,
#  8992,
#  5986,
#  4120,
#  9765,
#  4871,
#  1512,
#  2879,
#  916,
#  8905,
#  228,
#  9745,
#  3525,
#  2297,
#  436,
#  5112,
#  7166,
#  4979,
#  1328,
#  5926,
#  9490,
#  897,
#  4461,
#  5162,
#  4167,
#  5448,
#  6652,
#  803,
#  1404,
#  6495,
#  1144,
#  9642,
#  4904,
#  3610,
#  7649,
#  6519,
#  7673,
#  9784,
#  972,
#  4961,
#  3741,
#  6210,
#  6463,
#  5018,
#  1735,
#  4231,
#  9194,
#  9240,
#  2811,
#  4304,
#  9747,
#  7164,
#  6997,
#  2136,
#  7140,
#  4840,
#  7884,
#  6898,
#  63,
#  3445,
#  3294,
#  6896,
#  9546,
#  8801,
#  3947,
#  6104,
#  4661,
#  1933,
#  1910,
#  5146,
#  1642,
#  2040,
#  2141,
#  9937,
#  3646,
#  5524,
#  7763,
#  8500,
#  3427,
#  9585,
#  7362,
#  6696,
#  7352,
#  8323,
#  5078,
#  4772,
#  4050,
#  8818,
#  1454,
#  9160,
#  9750,
#  1524,
#  8348,
#  3866,
#  1287,
#  5144,
#  8642,
#  9412,
#  1369,
#  9135,
#  4673,
#  3856,
#  5201,
#  7171,
#  1651,
#  8280,
#  241,
#  1615,
#  8171,
#  9842,
#  6545,
#  2918,
#  3187,
#  2965,
#  9214,
#  9731,
#  2832,
#  5754,
#  5731,
#  1415,
#  6319,
#  1163,
#  6776,
#  7341,
#  1410,
#  2876,
#  6586,
#  8684,
#  5566,
#  748,
#  8904,
#  1635,
#  778,
#  5690,
#  2707,
#  9047,
#  1166,
#  9620,
#  5794,
#  6412,
#  6829,
#  8685,
#  9922,
#  3221,
#  271,
#  9656,
#  92,
#  9845,
#  4997,
#  7836,
#  2463,
#  5837,
#  9783,
#  6460,
#  6577,
#  3698,
#  4831,
#  4550,
#  8338,
#  3649,
#  443,
#  1542,
#  1526,
#  1126,
#  9025,
#  3037,
#  9309,
#  5182,
#  9849,
#  7251,
#  2470,
#  5813,
#  77,
#  3777,
#  8231,
#  4705,
#  9451,
#  3091,
#  6045,
#  7184,
#  7095,
#  1792,
#  2847,
#  1334,
#  5709,
#  7394,
#  1029,
#  2462,
#  1049,
#  5136,
#  2530,
#  4259,
#  422,
#  4713,
#  5052,
#  2419,
#  5941,
#  8867,
#  2383,
#  3038,
#  1916,
#  1562,
#  4684,
#  3166,
#  6762,
#  1580,
#  2298,
#  4305,
#  8421,
#  9096,
#  5103,
#  6833,
#  3808,
#  883,
#  6520,
#  8388,
#  4168,
#  4544,
#  2481,
#  2398,
#  421,
#  1015,
#  2575,
#  5065,
#  3397,
#  5577,
#  4931,
#  8088,
#  660,
#  1578,
#  5598,
#  8209,
#  6810,
#  5739,
#  849,
#  4815,
#  5420,
#  1009,
#  5774,
#  9715,
#  2499,
#  3680,
#  1773,
#  3280,
#  6979,
#  8414,
#  9651,
#  2384,
#  1710,
#  6092,
#  7879,
#  6792,
#  1847,
#  5134,
#  937,
#  3455,
#  8445,
#  893,
#  6500,
#  8146,
#  177,
#  688,
#  6624,
#  4938,
#  8267,
#  9691,
#  1800,
#  6387,
#  2157,
#  6241,
#  3509,
#  9503,
#  8652,
#  6421,
#  2862,
#  107,
#  8559,
#  8538,
#  7981,
#  5607,
#  3761,
#  3121,
#  492,
#  5868,
#  6920,
#  1011,
#  1648,
#  5353,
#  2666,
#  7266,
#  9652,
#  2717,
#  4819,
#  2997,
#  878,
#  350,
#  6276,
#  2703,
#  2923,
#  1581,
#  7670,
#  9711,
#  800,
#  1058,
#  7677,
#  989,
#  1177,
#  3670,
#  2203,
#  3719,
#  4885,
#  3347,
#  5800,
#  7726,
#  1863,
#  8871,
#  1758,
#  7282,
#  3161,
#  3377,
#  5365,
#  7062,
#  692,
#  9134,
#  7556,
#  7437,
#  5664,
#  6670,
#  7943,
#  3865,
#  6913,
#  7180,
#  6394,
#  9805,
#  2907,
#  5833,
#  9510,
#  1110,
#  6297,
#  7440,
#  5602,
#  6003,
#  1408,
#  3641,
#  6885,
#  9749,
#  2996,
#  7492,
#  8439,
#  9578,
#  4813,
#  4475,
#  7483,
#  4084,
#  651,
#  3124,
#  13,
#  2699,
#  2940,
#  2048,
#  5143,
#  2978,
#  3441,
#  7893,
#  8210,
#  7999,
#  6336,
#  5305,
#  6720,
#  1528,
#  3774,
#  9874,
#  6193,
#  7998,
#  1530,
#  5321,
#  1682,
#  9502,
#  9761,
#  3607,
#  4741,
#  6949,
#  6356,
#  6566,
#  9604,
#  7306,
#  2325,
#  485,
#  6309,
#  3839,
#  7442,
#  2795,
#  5890,
#  3991,
#  474,
#  6493,
#  1810,
#  8484,
#  3090,
#  785,
#  6687,
#  7966,
#  7178,
#  3141,
#  4298,
#  4653,
#  53,
#  4521,
#  7888,
#  1649,
#  1326,
#  4353,
#  6307,
#  5950,
#  5589,
#  740,
#  9471,
#  8269,
#  1973,
#  8370,
#  6481,
#  5613,
#  2690,
#  5982,
#  550,
#  9202,
#  6680,
#  4595,
#  126,
#  8640,
#  8057,
#  1961,
#  8253,
#  2351,
#  394,
#  5820,
#  3639,
#  8814,
#  2643,
#  791,
#  1080,
#  9566,
#  2785,
#  802,
#  2090,
#  4061,
#  9382,
#  5499,
#  1636,
#  8472,
#  6056,
#  720,
#  5907,
#  4574,
#  1715,
#  1207,
#  9173,
#  3664,
#  8194,
#  7231,
#  1173,
#  9483,
#  7742,
#  6708,
#  4557,
#  3922,
#  6340,
#  3769,
#  3066,
#  3687,
#  9186,
#  6044,
#  9144,
#  7992,
#  1539,
#  8866,
#  648,
#  1117,
#  4463,
#  6768,
#  8813,
#  5197,
#  7714,
#  7680,
#  2301,
#  5849,
#  2104,
#  2072,
#  7630,
#  6137,
#  834,
#  2440,
#  3542,
#  3497,
#  1313,
#  8924,
#  4186,
#  9487,
#  3312,
#  5030,
#  5814,
#  3228,
#  6790,
#  9541,
#  3007,
#  7067,
#  9353,
#  5718,
#  5083,
#  8634,
#  3852,
#  8432,
#  4258,
#  6843,
#  6980,
#  8015,
#  2894,
#  1297,
#  5501,
#  9786,
#  6692,
#  2347,
#  9322,
#  4318,
#  6676,
#  6199,
#  143,
#  6153,
#  2208,
#  433,
#  5255,
#  8983,
#  9782,
#  835,
#  2850,
#  1696,
#  5783,
#  4516,
#  5004,
#  5388,
#  2638,
#  301,
#  8355,
#  3052,
#  7544,
#  4607,
#  3760,
#  2149,
#  1190,
#  658,
#  9323,
#  2416,
#  304,
#  1474,
#  8491,
#  3114,
#  5099,
#  9148,
#  2992,
#  6667,
#  1550,
#  925,
#  8820,
#  7206,
#  3202,
#  8697,
#  9978,
#  9603,
#  2864,
#  1383,
#  9889,
#  3735,
#  1354,
#  8144,
#  5779,
#  3286,
#  9317,
#  6087,
#  9211,
#  9517,
#  218,
#  6665,
#  9006,
#  9390,
#  9990,
#  9606,
#  8022,
#  7379,
#  5171,
#  6425,
#  3274,
#  5910,
#  9504,
#  9771,
#  9049,
#  1508,
#  3897,
#  8601,
#  8366,
#  7897,
#  5160,
#  7312,
#  6417,
#  3913,
#  6224,
#  8350,
#  1824,
#  141,
#  7193,
#  1387,
#  9218,
#  9824,
#  2552,
#  9097,
#  1894,
#  1352,
#  7267,
#  2937,
#  5050,
#  5675,
#  9582,
#  9100,
#  6959,
#  3755,
#  9155,
#  3874,
#  9358,
#  4990,
#  8571,
#  5798,
#  5352,
#  7123,
#  3617,
#  7757,
#  4753,
#  9464,
#  9054,
#  7995,
#  6275,
#  5426,
#  4300,
#  3367,
#  6583,
#  8510,
#  5477,
#  8123,
#  4044,
#  8817,
#  2456,
#  3320,
#  8991,
#  5039,
#  6783,
#  7057,
#  4419,
#  7803,
#  9123,
#  8570,
#  9369,
#  6159,
#  5511,
#  112,
#  8888,
#  9932,
#  9639,
#  2160,
#  8321,
#  6232,
#  2500,
#  6465,
#  654,
#  1730,
#  441,
#  1134,
#  49,
#  283,
#  9958,
#  2028,
#  9797,
#  6506,
#  6094,
#  3723,
#  5091,
#  2315,
#  5407,
#  524,
#  3881,
#  46,
#  4611,
#  3465,
#  94,
#  2723,
#  6529,
#  4638,
#  4657,
#  6357,
#  6876,
#  3132,
#  954,
#  3335,
#  9795,
#  5116,
#  5830,
#  5199,
#  124,
#  390,
#  481,
#  2295,
#  6976,
#  8812,
#  6355,
#  3004,
#  9378,
#  5295,
#  8098,
#  8288,
#  7513,
#  4582,
#  2750,
#  1624,
#  5637,
#  5755,
#  7230,
#  4239,
#  7604,
#  5043,
#  3036,
#  127,
#  9242,
#  4615,
#  854,
#  9205,
#  7882,
#  2423,
#  570,
#  6547,
#  7016,
#  182,
#  7420,
#  256,
#  9882,
#  3595,
#  4498,
#  8528,
#  5398,
#  8128,
#  1106,
#  3313,
#  7800,
#  1728,
#  3605,
#  6424,
#  1195,
#  6534,
#  8188,
#  9739,
#  8268,
#  7058,
#  327,
#  6301,
#  1895,
#  2210,
#  150,
#  6705,
#  850,
#  7915,
#  9027,
#  1293,
#  3164,
#  3285,
#  6991,
#  1007,
#  3571,
#  2576,
#  7866,
#  5968,
#  8974,
#  9269,
#  4117,
#  8420,
#  3446,
#  9927,
#  1035,
#  5730,
#  9179,
#  7991,
#  5535,
#  709,
#  4009,
#  2773,
#  1093,
#  9352,
#  1291,
#  3196,
#  8756,
#  6984,
#  1219,
#  5626,
#  7265,
#  2895,
#  6058,
#  7476,
#  8437,
#  1623,
#  9880,
#  5822,
#  2397,
#  8858,
#  7651,
#  5022,
#  5561,
#  7154,
#  1071,
#  6823,
#  5903,
#  1868,
#  926,
#  4852,
#  8889,
#  9714,
#  9075,
#  2216,
#  7117,
#  9488,
#  3429,
#  7554,
#  9312,
#  3710,
#  3399,
#  4316,
#  2609,
#  9814,
#  8218,
#  9893,
#  1756,
#  7015,
#  4703,
#  8328,
#  8666,
#  7828,
#  1097,
#  7486,
#  2825,
#  8542,
#  5952,
#  6613,
#  5887,
#  1860,
#  6106,
#  6476,
#  2280,
#  9029,
#  9103,
#  1522,
#  2313,
#  2921,
#  5461,
#  9060,
#  6432,
#  5129,
#  5152,
#  2489,
#  2209,
#  2043,
#  6590,
#  3105,
#  1274,
#  845,
#  7799,
#  7721,
#  4805,
#  4743,
#  2726,
#  4472,
#  4953,
#  2144,
#  7615,
#  6756,
#  1823,
#  5482,
#  6271,
#  5126,
#  3684,
#  2569,
#  2155,
#  2485,
#  2375,
#  595,
#  6204,
#  5073,
#  4731,
#  1385,
#  6574,
#  2556,
#  3415,
#  1654,
#  26,
#  2467,
#  4718,
#  4512,
#  9902,
#  25,
#  904,
#  5604,
#  4535,
#  5485,
#  7697,
#  9132,
#  5471,
#  1797,
#  3981,
#  5174,
#  1056,
#  5537,
#  7045,
#  851,
#  2121,
#  3692,
#  4748,
#  1854,
#  6311,
#  9621,
#  7219,
#  5458,
#  2095,
#  6103,
#  3216,
#  3758,
#  9425,
#  5984,
#  2928,
#  6141,
#  3250,
#  7585,
#  3211,
#  2714,
#  8416,
#  1465,
#  3491,
#  6999,
#  1592,
#  4568,
#  1003,
#  2844,
#  8549,
#  8339,
#  1018,
#  5574,
#  5787,
#  5170,
#  ...]

# %%
def seq_search(arr, e):
    '''sequntial search for unordered list'''
    pos = 0
    found = False
    while pos<len(arr) and not found:
        if arr[pos]==e:
            found=True
            break
        else:
            pos=pos+1
    return found, pos


arr = [10,100,3,2,1]
e = 100
seq_search(arr,e)


arr = [10,20,30,40,50]
e = 25
# Out:
# (True, 1)

# %%
def ordered_seq_search(arr,ele):
    """
    Sequential search for an Ordered list
    """
    # Start at position 0
    pos = 0
    
    # Target becomes true if ele is in the list
    found = False
    
    # Stop marker
    stopped = False
    
    # go until end of list
    while pos < len(arr) and not found and not stopped:
        
        # If match
        if arr[pos] == ele:
            found = True
            
        else:
            
            # Check if element is greater
            if arr[pos] > ele:
                stopped = True
                
            # Otherwise move on
            else:
                pos  = pos+1
    
    return found

# %%
start = time()
print(start)
seq_search(l, 5000)
end = time()
print(end)
print(f'time taken: {end-start:.50f} seconds')
# Out:
# 1566715953.7077186
# 1566715953.7087164
# time taken: 0.00099778175354003906250000000000000000000000000000 seconds

# %%
l.sort()
start = time()
ordered_seq_search(l, 5000)
end = time()
print(f'time taken: {end-start:.50f} seconds')
# Out:
# time taken: 0.00099658966064453125000000000000000000000000000000 seconds

# %%
def binarySearch (arr, l, r, x): 
  
    # Check base case 
    if r >= l: 
  
        mid = int(l + (r - l)/2)
  
        # If element is present at the middle itself 
        if arr[mid] == x: 
            return mid 
          
        # If element is smaller than mid, then it  
        # can only be present in left subarray 
        elif arr[mid] > x: 
            return binarySearch(arr, l, mid-1, x) 
  
        # Else the element can only be present  
        # in right subarray 
        else: 
            return binarySearch(arr, mid + 1, r, x) 
  
    else: 
        # Element is not present in the array 
        return 'not found'

# Test array 
arr = [ 5, 10, 15, 20] 
x = 15
  
# Function call 
result = binarySearch(arr, 0, len(arr)-1, x) 
  
if result != -1: 
    print("Element is present at index: ", result) 
else: 
    print("Element is not present in array")
# Out:
# Element is present at index:  2

# %%
import math

math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
x = int(1.7)
x
# Out:
# 1
